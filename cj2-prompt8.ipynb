# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 1, 100)

# %%
def compute_sin(x):
    return np.sin(x)

# %%
def compute_cos(x):
    return np.cos(x)

# %%
sinx = compute_sin(x)
cosx = compute_cos(x)

figure, axes = plt.subplots(1, 2)

axes[0].plot(x,sinx)
axes[0].set_xlabel('x')
axes[0].set_ylabel('sin(x)')
axes[0].set_title(r'$\sin(x)$')

axes[1].plot(x,cosx)
axes[1].set_xlabel('x')
axes[1].set_ylabel('cos(x)')
axes[1].set_title(r'$\cos(x)$')

figure.subplots_adjust(wspace=0.3)

plt.savefig('SinAndCos.pdf', bbox_inches='tight', dpi=600)  # Check again what these mean in book
