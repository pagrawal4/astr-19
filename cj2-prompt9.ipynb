# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.rand(1000)  # Generate 1000 random data values between 0 and 1

# %%
# print(x)
bins = np.linspace(0.0, 1.0, 101)
plt.hist(x, bins=bins, alpha=0.5, edgecolor='black')
plt.xlabel('X')
plt.ylabel('Counts')

plt.savefig('Histogram.pdf', bbox_inches='tight', dpi=600)
