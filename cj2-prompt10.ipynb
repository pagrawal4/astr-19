# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.binomial(n=1000, p=0.5, size=1000)

# %%
plt.hist(x, bins=100)
plt.xlabel('Range of Values')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
