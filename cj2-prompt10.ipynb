# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.triangular(left=0, right=100, mode=50, size=1000) # Gets 1000 numbers from Triangular Dist.

# %%
bins = np.linspace(0, 100, 101) # 101 values will give 100 bins [0,1), [1,2),...[99,100]
plt.hist(x, bins=bins)
plt.xlabel('X')
plt.ylabel('Counts')

plt.savefig('TriangularHistogram.pdf', bbox_inches='tight', dpi=600)
